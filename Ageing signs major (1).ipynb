# %%
import os
import cv2

# %%
features=[]
target=[]

# %%
for x in["darkspots","puffyeyes","wrinkles","clear face"]:
    ImagesNamesList=os.listdir("/content/drive/MyDrive/Ageing_signs_dataset" + "/" + str(x))
    for y in ImagesNamesList:
        Imgarr=cv2.imread("/content/drive/MyDrive/Ageing_signs_dataset" + "/" + str(x) + "/" + y)
        try:
            Imgarr=cv2.resize(Imgarr,(244,244))
            features.append(Imgarr)
        except:
            pass
        else:
            if x=="darkspots":
              target.append(0)
            elif x=="puffyeyes":
              target.append(1) 
            elif x=="wrinkles":
               target.append(2)    
            else:
                target.append(3)
    print("In Folder", x)
# Out:
# In Folder darkspots
# In Folder puffyeyes
# In Folder wrinkles
# In Folder clear face

# %%
import numpy as np

# %%
features=np.array(features)
target=np.array(target)

# %%
features.shape
# Out:
# (1596, 244, 244, 3)

# %%
target.shape
# Out:
# (1596,)

# %%
from sklearn.model_selection import train_test_split

# %%
features_train,features_test,target_train,target_test=train_test_split(features,target,test_size=0.2)

# %%
features_train.shape
# Out:
# (1276, 244, 244, 3)

# %%
target_train.shape
# Out:
# (1276,)

# %%
features_test.shape
# Out:
# (320, 244, 244, 3)

# %%
target_test.shape
# Out:
# (320,)

# %%
def preprocessing(image):
    image=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
    image=image/255

    
    
    return image

# %%
features_train=np.array(list(map(preprocessing,features_train)))

# %%
features_train=features_train.reshape(1276,244,244,1)

# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
dataGen=ImageDataGenerator(rotation_range=10,width_shift_range=0.1,height_shift_range=0.1,zoom_range=0.2,shear_range=0.1)

# %%
dataGen.fit(features_train)

# %%
batches=dataGen.flow(features_train,target_train,batch_size=20)

# %%
images,labels=next(batches)

# %%
images.shape
# Out:
# (20, 244, 244, 1)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,10))
for i in range(0,20):
    plt.subplot(4,5,i+1)
    plt.imshow(images[i].reshape(244,244))
plt.show()

# %%
from tensorflow.keras.utils import to_categorical

# %%
target_train=to_categorical(target_train)

# %%
target_train.shape
# Out:
# (1276, 4)

# %%
features_train.shape
# Out:
# (1276, 244, 244, 1)

# %%
from keras.layers import Dense,Flatten,Conv2D,MaxPooling2D,Dropout
from keras.models import Sequential
from tensorflow.keras.applications import EfficientNetB0

# %%
conv_base=EfficientNetB0(weights="imagenet",include_top=False,input_shape=(244,244,3))
model=Sequential()
model.add(conv_base)
model.add(MaxPooling2D((3,3)))
model.add(Dropout(0.4))
model.add(Flatten())
model.add(Dense(4,activation="sigmoid"))
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16711680/16705208 [==============================] - 0s 0us/step

# %%
from keras.optimizers import Adam

# %%
model.compile(Adam(learning_rate=0.001),loss="binary_crossentropy",metrics=["accuracy"])

# %%
model.fit(dataGen.flow(features_train,target_train,batch_size=20),epochs=20)
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 244, 244, 3) for input KerasTensor(type_spec=TensorSpec(shape=(None, 244, 244, 3), dtype=tf.float32, name='input_1'), name='input_1', description="created by layer 'input_1'"), but it was called on an input with incompatible shape (20, 244, 244, 1).
# Epoch 1/20
# 64/64 [==============================] - 42s 245ms/step - loss: 0.6764 - accuracy: 0.5625
# Epoch 2/20
# 64/64 [==============================] - 15s 232ms/step - loss: 0.1860 - accuracy: 0.8651
# Epoch 3/20
# 64/64 [==============================] - 15s 234ms/step - loss: 0.1448 - accuracy: 0.8930
# Epoch 4/20
# 64/64 [==============================] - 15s 236ms/step - loss: 0.1142 - accuracy: 0.9296
# Epoch 5/20
# 64/64 [==============================] - 15s 238ms/step - loss: 0.1122 - accuracy: 0.9268
# Epoch 6/20
# 64/64 [==============================] - 15s 239ms/step - loss: 0.0801 - accuracy: 0.9467
# Epoch 7/20
# 64/64 [==============================] - 15s 237ms/step - loss: 0.0909 - accuracy: 0.9426
# Epoch 8/20
# 64/64 [==============================] - 15s 237ms/step - loss: 0.0631 - accuracy: 0.9665
# Epoch 9/20
# 64/64 [==============================] - 15s 236ms/step - loss: 0.0584 - accuracy: 0.9675
# Epoch 10/20
# 64/64 [==============================] - 15s 238ms/step - loss: 0.0778 - accuracy: 0.9581
# Epoch 11/20
# 64/64 [==============================] - 15s 238ms/step - loss: 0.0595 - accuracy: 0.9675
# Epoch 12/20
# 64/64 [==============================] - 15s 238ms/step - loss: 0.0494 - accuracy: 0.9676
# Epoch 13/20
# 64/64 [==============================] - 15s 239ms/step - loss: 0.0531 - accuracy: 0.9626
# Epoch 14/20
# 64/64 [==============================] - 15s 236ms/step - loss: 0.0611 - accuracy: 0.9681
# Epoch 15/20
# 64/64 [==============================] - 15s 237ms/step - loss: 0.0514 - accuracy: 0.9659
# Epoch 16/20
# 64/64 [==============================] - 15s 238ms/step - loss: 0.0456 - accuracy: 0.9744
# Epoch 17/20
# 64/64 [==============================] - 15s 237ms/step - loss: 0.0342 - accuracy: 0.9737
# Epoch 18/20
# 64/64 [==============================] - 15s 237ms/step - loss: 0.0533 - accuracy: 0.9619
# Epoch 19/20
# 64/64 [==============================] - 15s 237ms/step - loss: 0.0640 - accuracy: 0.9658
# Epoch 20/20
# 64/64 [==============================] - 15s 236ms/step - loss: 0.0252 - accuracy: 0.9874

# %%
import numpy as np
import cv2

# %%
from google.colab.patches import cv2_imshow
import argparse

image=cv2.imread("/content/drive/MyDrive/03198defbf9905613bedbbdd2323228d.jpg")
imagearr=np.asarray(image)
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades +"haarcascade_frontalface_default.xml")
gray=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
faces=face_cascade.detectMultiScale(gray,1.05,5)
labels=np.array(['darkspots','wrinkles','puffyeyes','clear face'],dtype='object')
for (x,y,w,h) in faces:
    detectedFace=image[x:x+w,y:y+h]
    detectedFace=cv2.resize(detectedFace,(244,244))
    detectedFace=preprocessing(detectedFace)
    detectedFace=detectedFace.reshape(1,244,244,1)
    predictions=model.predict(detectedFace)[0]
     
    cv2.rectangle(image,(x,y),(x+w,y+h),(0,0,255),2)
    count =1
    for i in predictions:
       classname=labels[np.where(predictions==i)]
       accuracy=i*100
       label="{}:{:.2f}%".format(classname,accuracy)
       cv2.putText(image,label,(10,count *30+25),cv2.FONT_HERSHEY_SIMPLEX,1,(0,0,200),2)
       count +=1
       print(predictions)
    cv2_imshow(image)
    returnedValue=cv2.waitKey(1)
    if returnedValue==ord("s") or returnedValue==ord("S"):
       cv2.destroyAllWindows()
       break
# Out:
# [0.01839489 0.89683807 0.00131886 0.01358343]
# [0.01839489 0.89683807 0.00131886 0.01358343]
# [0.01839489 0.89683807 0.00131886 0.01358343]
# [0.01839489 0.89683807 0.00131886 0.01358343]
# <PIL.Image.Image image mode=RGB size=333x500 at 0x7EFC2E211650>
# [4.9507832e-03 9.2261463e-01 5.3719420e-04 6.9406098e-03]
# [4.9507832e-03 9.2261463e-01 5.3719420e-04 6.9406098e-03]
# [4.9507832e-03 9.2261463e-01 5.3719420e-04 6.9406098e-03]
# [4.9507832e-03 9.2261463e-01 5.3719420e-04 6.9406098e-03]
# <PIL.Image.Image image mode=RGB size=333x500 at 0x7EFC2E2C2650>
